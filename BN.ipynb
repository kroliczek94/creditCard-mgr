# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import somoclu
import pandas as pd

# %%
dataset = pd.read_csv('http://sirius.cs.put.poznan.pl/~inf117242/DC.Inputs.csv')
dataset_answ = pd.read_csv('http://sirius.cs.put.poznan.pl/~inf117242/DC.Targets.csv', header=None, names=['Class'])
df_joined = dataset.join(dataset_answ)

# %%
df_filtered = df_joined.drop(['custAttr2', 'state1'], axis=1)

# %%
df_cut = df_filtered.head(100)
df_cut_train = df_filtered.iloc[50:100]
#df_cut_train["Class"] = None
print(df_cut_train)
# Out:
#     amount  hour1  zip1         custAttr1  field1  field2  hour2  flag1  \
# 50   38.85      6   708  1234567890123504       2       1      6      0
# 51   11.01      6   947  1234567890123505       3       1      6      1
# 52   12.95      6   947  1234567890123505       3       1      6      1
# 53   38.85      6   303  1234567890123506       3       1      6      1
# 54   12.95      6   770  1234567890123507       3       0      6      1
# 55   38.85      7    91  1234567890123508       3       0      7      0
# 56   49.95      7   378  1234567890123509       3       1      7      0
# 57   59.40      7   100  1234567890123510       3       0      7      0
# 58   12.95      7   330  1234567890123511       0       0      7      1
# 59   10.36      7    21  1234567890123512       2       0      7      1
# 60   38.85      7   207  1234567890123513       3       1      7      0
# 61   38.85      7   963  1234567890123514       3       0      7      0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
data = sc.fit_transform(df_cut)
data_train = sc.fit_transform(df_cut_train)

data_train[:, -1] = None
print(data_train)
# Out:
# [[0.58095432 0.         0.72929936 0.         0.66666667 1.
#   0.         0.         0.58095432 0.71300215 0.76923077 0.
#   0.         0.         0.         0.         0.                nan]
#  [0.01325449 0.         0.98301486 0.0234375  1.         1.
#   0.         1.         0.01325449 0.51136142 0.03846154 0.
#   0.         1.         1.         0.         1.                nan]
#  [0.05281403 0.         0.98301486 0.0234375  1.         1.
#   0.         1.         0.05281403 0.51136142 0.03846154 0.
#   0.         1.         1.         0.         1.                nan]
#  [0.58095432 0.         0.29936306 0.04296875 1.         1.
#   0.         1.         0.58095432 0.85695683 0.03846154 0.
#   0.         1.         1.         0.         1.                nan]
#  [0.05281403 0.         0.79511677 0.06640625 1.         0.
#   0.         1.         0.05281403 0.79074158 0.         1.
#   0.         0.         1.         0.         0.33333333        nan]
# ...

# %%
df_joined.groupby(['custAttr1'])['Class'].agg(['sum', 'count']).sort_values('count', ascending=False)

# for count also consider 'size'. size will return n for NaN values also, whereas 'count' will not.
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sum</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>custAttr1</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1234567890124236</th>
#       <td>0</td>
#       <td>68</td>
#     </tr>
#     <tr>
#       <th>1234567890139015</th>
#       <td>49</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>1234567890124580</th>
#       <td>0</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>1234567890125395</th>
#       <td>0</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>1234567890141164</th>
#       <td>0</td>
# ...

# %%
#!pip install pomegranate
from pomegranate import *
import numpy

#X = numpy.load('data.npy')
model = BayesianNetwork.from_samples(df_cut,algorithm='greedy')

# %%
# Defining the Bayesian Model

from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel()
model.add_node('Class')

# Fitting the data to the model using Maximum Likelihood Estimator
model.fit(df_cut[1:70], estimator=MaximumLikelihoodEstimator)
print(model)

# %%
from pomegranate import *
import numpy

print(data)
model = BayesianNetwork.from_samples(data[1:70],
                algorithm='chow-liu', verbose=True)
# Out:
# [[0.05281403 0.         1.         ... 0.         0.         0.        ]
#  [0.58095432 0.         0.99385246 ... 0.         0.         0.        ]
#  [0.58095432 0.         0.40163934 ... 0.         0.         0.        ]
#  ...
#  [0.         1.         0.29918033 ... 0.         0.33333333 0.        ]
#  [0.58095432 1.         0.53483607 ... 0.         0.         0.        ]
#  [0.05281403 1.         0.9375     ... 0.         0.         0.        ]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-082924e89b9e> in <module>()
#       4 print(data)
#       5 model = BayesianNetwork.from_samples(data[1:70],
# ----> 6                 algorithm='chow-liu', verbose=True)
#
# pomegranate/BayesianNetwork.pyx in pomegranate.BayesianNetwork.BayesianNetwork.from_samples()
#
# TypeError: from_samples() got an unexpected keyword argument 'verbose'

# %%
x = model.predict(data_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-a0f00df622dd> in <module>()
# ----> 1 x = model.predict(data_train)
#
# pomegranate/BayesianNetwork.pyx in pomegranate.BayesianNetwork.BayesianNetwork.predict()
#
# pomegranate/BayesianNetwork.pyx in pomegranate.BayesianNetwork.BayesianNetwork.predict_proba()
#
# pomegranate/BayesianNetwork.pyx in pomegranate.BayesianNetwork._check_input()
#
# ValueError: State '2' does not have key '0.7292993630573248'
